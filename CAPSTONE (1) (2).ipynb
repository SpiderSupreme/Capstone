# %% [markdown]
# DOING THE API CALL TO FETCH THE DATA FROM FRANKFURTER.APP

# %%
import requests    #import module to get the data
r = requests.get('https://api.frankfurter.app/latest')   #send a get request to retrieve the response, get a response object
r.status_code   #Get the status..returns an integer on success
r.text    #load the data
r.json()  #get data in a more readable json format'''
# Out:
# {'amount': 1.0,
#  'base': 'EUR',
#  'date': '2022-07-11',
#  'rates': {'AUD': 1.491,
#   'BGN': 1.9558,
#   'BRL': 5.3673,
#   'CAD': 1.314,
#   'CHF': 0.9908,
#   'CNY': 6.7793,
#   'CZK': 24.592,
#   'DKK': 7.4414,
#   'GBP': 0.8454,
#   'HKD': 7.9265,
#   'HRK': 7.518,
#   'HUF': 408.22,
#   'IDR': 15132,
#   'ILS': 3.5108,
#   'INR': 80.24,
#   'ISK': 139.3,
#   'JPY': 138.77,
#   'KRW': 1320.36,
#   'MXN': 20.784,
#   'MYR': 4.4704,
#   'NOK': 10.299,
#   'NZD': 1.6466,
#   'PHP': 56.574,
#   'PLN': 4.7968,
#   'RON': 4.943,
#   'SEK': 10.6943,
#   'SGD': 1.4178,
#   'THB': 36.585,
#   'TRY': 17.5447,
#   'USD': 1.0098,
#   'ZAR': 17.1634}}

# %% [markdown]
# DEFINING THE FUNCTION TO FETCH THE DATA FROM 1999-01-01 TO 2022-01-01

# %%
import json
import pandas as pd
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
Dict= { 'base' : 'EUR'
    
}

# %% [markdown]
# CALLING THE FUNCTION TO READ THE DATA FROM 1999-01-01 TO 2022-01-01

# %%
r1 = requests.get("https://api.frankfurter.app/1999-01-01..2022-01-01",Dict)
#r1
jprint(r1.json())
# Out:
# {
#     "amount": 1.0,
#     "base": "EUR",
#     "end_date": "2021-12-27",
#     "rates": {
#         "1999-01-04": {
#             "AUD": 1.8749,
#             "CAD": 1.7785,
#             "CHF": 1.6142,
#             "CYP": 0.58207,
#             "CZK": 34.94,
#             "DKK": 7.4462,
#             "EEK": 15.6466,
#             "GBP": 0.70923,
#             "HKD": 9.0823,
#             "HUF": 250.64,
#             "ISK": 81.32,
#             "JPY": 131.13,
#             "KRW": 1367.01,
#             "LTL": 4.6906,
#             "LVL": 0.6651,
#             "MTL": 0.44232,
#             "NOK": 8.7165,
#             "NZD": 2.1844,
#             "PLN": 4.031,
#             "ROL": 13136,
#             "SEK": 9.3044,
#             "SGD": 1.9576,
#             "SIT": 188.83,
#             "SKK": 42.788,
#             "TRL": 371851,
#             "USD": 1.1723,
#             "ZAR": 6.8156
#         },
#         "1999-01-11": {
#             "AUD": 1.8317,
# ...

# %%
r2=r1.json()
df=pd.DataFrame(r2)
df
# Out:
#             amount base  start_date    end_date  \
# 1999-01-04     1.0  EUR  1999-01-04  2021-12-27
# 1999-01-11     1.0  EUR  1999-01-04  2021-12-27
# 1999-01-18     1.0  EUR  1999-01-04  2021-12-27
# 1999-01-25     1.0  EUR  1999-01-04  2021-12-27
# 1999-02-01     1.0  EUR  1999-01-04  2021-12-27
# ...            ...  ...         ...         ...
# 2021-11-29     1.0  EUR  1999-01-04  2021-12-27
# 2021-12-06     1.0  EUR  1999-01-04  2021-12-27
# 2021-12-13     1.0  EUR  1999-01-04  2021-12-27
# 2021-12-20     1.0  EUR  1999-01-04  2021-12-27
# 2021-12-27     1.0  EUR  1999-01-04  2021-12-27
#
#                                                         rates
# 1999-01-04  {'AUD': 1.8749, 'CAD': 1.7785, 'CHF': 1.6142, ...
# 1999-01-11  {'AUD': 1.8317, 'CAD': 1.7696, 'CHF': 1.6005, ...
# 1999-01-18  {'AUD': 1.8209, 'CAD': 1.7625, 'CHF': 1.6008, ...
# 1999-01-25  {'AUD': 1.8274, 'CAD': 1.7478, 'CHF': 1.6064, ...
# 1999-02-01  {'AUD': 1.7613, 'CAD': 1.7014, 'CHF': 1.6019, ...
# ...

# %%
import json

with open('Capstone_json.json', 'w') as js_file:
    json.dump(r2, js_file)

# %%
with open('Capstone_json.json','r') as f:
    data = json.loads(f.read())

df_nested_list = pd.json_normalize(data, max_level = 2)

# %%
df = pd.melt(df_nested_list, id_vars = ['base', 'amount', 'start_date', 'end_date'])
df
# Out:
#       base  amount  start_date    end_date              variable     value
# 0      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.AUD   1.87490
# 1      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.CAD   1.77850
# 2      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.CHF   1.61420
# 3      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.CYP   0.58207
# 4      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.CZK  34.94000
# ...    ...     ...         ...         ...                   ...       ...
# 37603  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.SGD   1.53210
# 37604  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.THB  37.86400
# 37605  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.TRY  14.05330
# 37606  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.USD   1.13210
# 37607  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.ZAR  17.87980
#
# [37608 rows x 6 columns]

# %%
# split column and add new columns to df
df[['Rate', 'Date', 'Base']] = df['variable'].str.split('.', expand=True)
# display the dataframe
df
# Out:
#       base  amount  start_date    end_date              variable     value  \
# 0      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.AUD   1.87490
# 1      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.CAD   1.77850
# 2      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.CHF   1.61420
# 3      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.CYP   0.58207
# 4      EUR     1.0  1999-01-04  2021-12-27  rates.1999-01-04.CZK  34.94000
# ...    ...     ...         ...         ...                   ...       ...
# 37603  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.SGD   1.53210
# 37604  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.THB  37.86400
# 37605  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.TRY  14.05330
# 37606  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.USD   1.13210
# 37607  EUR     1.0  1999-01-04  2021-12-27  rates.2021-12-27.ZAR  17.87980
#
#         Rate        Date Base
# 0      rates  1999-01-04  AUD
# ...

# %%
df = df.drop(columns = 'variable')
df = df.drop(columns = 'Rate')

# %%
df_EUR=df.to_csv('EUR_Currency.csv', index = False)

# %%
#df_CAD = pd.read_csv('CAD_Currency.csv')
#df_INR = pd.read_csv('INR_Currency.csv')
df_EUR = pd.read_csv('EUR_Currency.csv')
#df_CHF = pd.read_csv('CHF_Currency.csv')
#df_IDR = pd.read_csv('IDR_Currency.csv')

# %%
df_EUR = df.rename(columns = {"Base":"currency"})
df_EUR
# Out:
#       base  amount  start_date    end_date     value        Date currency
# 0      EUR     1.0  1999-01-04  2021-12-27   1.87490  1999-01-04      AUD
# 1      EUR     1.0  1999-01-04  2021-12-27   1.77850  1999-01-04      CAD
# 2      EUR     1.0  1999-01-04  2021-12-27   1.61420  1999-01-04      CHF
# 3      EUR     1.0  1999-01-04  2021-12-27   0.58207  1999-01-04      CYP
# 4      EUR     1.0  1999-01-04  2021-12-27  34.94000  1999-01-04      CZK
# ...    ...     ...         ...         ...       ...         ...      ...
# 37603  EUR     1.0  1999-01-04  2021-12-27   1.53210  2021-12-27      SGD
# 37604  EUR     1.0  1999-01-04  2021-12-27  37.86400  2021-12-27      THB
# 37605  EUR     1.0  1999-01-04  2021-12-27  14.05330  2021-12-27      TRY
# 37606  EUR     1.0  1999-01-04  2021-12-27   1.13210  2021-12-27      USD
# 37607  EUR     1.0  1999-01-04  2021-12-27  17.87980  2021-12-27      ZAR
#
# [37608 rows x 7 columns]

# %%
frames = [df_CHF, df_CAD, df_EUR, df_USD, df_IDR, df_INR]
result=pd.concat(frames)

# %%
result.to_csv('Currency.csv', index = False)

# %%
import pandas_profiling as pp

# %%
profile = pp.ProfileReport(result)
profile.to_file("Final_Output2.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
result.info
# Out:
# <bound method DataFrame.info of       base  amount  start_date    end_date     value        Date currency
# 0      CHF     1.0  1999-01-04  2021-12-27   1.16150  1999-01-04      AUD
# 1      CHF     1.0  1999-01-04  2021-12-27   1.10180  1999-01-04      CAD
# 2      CHF     1.0  1999-01-04  2021-12-27   0.36059  1999-01-04      CYP
# 3      CHF     1.0  1999-01-04  2021-12-27  21.64500  1999-01-04      CZK
# 4      CHF     1.0  1999-01-04  2021-12-27   4.61290  1999-01-04      DKK
# ...    ...     ...         ...         ...       ...         ...      ...
# 21826  INR     1.0  2008-12-29  2021-12-27   0.01814  2021-12-27      SGD
# 21827  INR     1.0  2008-12-29  2021-12-27   0.44831  2021-12-27      THB
# 21828  INR     1.0  2008-12-29  2021-12-27   0.16639  2021-12-27      TRY
# 21829  INR     1.0  2008-12-29  2021-12-27   0.01340  2021-12-27      USD
# 21830  INR     1.0  2008-12-29  2021-12-27   0.21170  2021-12-27      ZAR
#
# [200851 rows x 7 columns]>

# %%
result.describe()
# Out:
#          amount         value
# count  200851.0  2.008510e+05
# mean        1.0  6.396805e+03
# std         0.0  8.415518e+04
# min         1.0  3.100000e-05
# 25%         1.0  4.547800e-01
# 50%         1.0  2.734200e+00
# 75%         1.0  1.377590e+01
# max         1.0  1.892060e+06

# %%
result.isna().sum()
# Out:
# base          0
# amount        0
# start_date    0
# end_date      0
# value         0
# Date          0
# currency      0
# dtype: int64

# %%
result.duplicated().sum()
# Out:
# 0

# %%
import yaml

# %%
article_info = [
    {
        'Details': 
        {
        'ACCESS_KEY_ID' : 'AKIAW4VH6ZIBRISBOWUZ',
        'ACCESS_SECRET_KEY' : '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'
        }
    }
]

with open("S3_info.yaml", 'w') as yamlfile:
    data = yaml.dump(article_info, yamlfile)
    print("Write successful")
# Out:
# Write successful

# %%
import boto3

bucket = "capstonecurrency"
s3_client = boto3.client('s3')
response = s3_client.get_object(Bucket=bucket, Key="S3_info.yaml")

try:
    configfile = yaml.safe_load(response["Body"])
except yaml.YAMLError as exc:
    return exc
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Input In [194], in <cell line: 5>()
#       3 bucket = "bucket"
#       4 s3_client = boto3.client('s3')
# ----> 5 response = s3_client.get_object(Bucket=bucket, Key="S3_info.yaml")
#       7 try:
#       8     configfile = yaml.safe_load(response["Body"])
#
# File ~\Anaconda3\lib\site-packages\botocore\client.py:401, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     398     raise TypeError(
#     399         "%s() only accepts keyword arguments." % py_operation_name)
#     400 # The "self" in this scope is referring to the BaseClient.
# --> 401 return self._make_api_call(operation_name, kwargs)
#
# File ~\Anaconda3\lib\site-packages\botocore\client.py:717, in BaseClient._make_api_call(self, operation_name, api_params)
#     715 else:
#     716     apply_request_checksum(request_dict)
# ...

# %%
import boto3
from botocore.client import Config

bucket = 'capstonecurrency'
response = s3_client.get_object(Bucket=bucket, Key="S3_info.yaml")

data = open('currency.csv', 'rb')

s3 = boto3.resource(
    's3',
    configfile = yaml.safe_load(response["Body"])
)
s3.Bucket(BUCKET_NAME).put_object(Key='currency.csv', Body=data)

print ("Done")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Input In [202], in <cell line: 5>()
#       2 from botocore.client import Config
#       4 bucket = 'capstonecurrency'
# ----> 5 response = s3_client.get_object(Bucket=bucket, Key="S3_info.yaml")
#       7 data = open('currency.csv', 'rb')
#       9 s3 = boto3.resource(
#      10     's3',
#      11     configfile = yaml.safe_load(response["Body"])
#      12 )
#
# File ~\Anaconda3\lib\site-packages\botocore\client.py:401, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     398     raise TypeError(
#     399         "%s() only accepts keyword arguments." % py_operation_name)
#     400 # The "self" in this scope is referring to the BaseClient.
# --> 401 return self._make_api_call(operation_name, kwargs)
#
# ...

# %%
import boto3
from botocore.client import Config

credentials = yaml.load(open('C:\python\.yml'))

username = credentials['database']['username']
BUCKET_NAME = 'capstonecurrency'

data = open('currency.csv', 'rb')

s3 = boto3.resource(
    's3',
    credentials = yaml.load(open('./credentials.yml'))

# access values from dictionary
username = credentials['database']['username']
    config=Config(signature_version='s3v4')
)
s3.Bucket(BUCKET_NAME).put_object(Key='currency.csv', Body=data)

print ("Done")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Input In [204], in <cell line: 16>()
#       8 data = open('currency.csv', 'rb')
#      10 s3 = boto3.resource(
#      11     's3',
#      12     aws_access_key_id=ACCESS_KEY_ID,
#      13     aws_secret_access_key=ACCESS_SECRET_KEY,
#      14     config=Config(signature_version='s3v4')
#      15 )
# ---> 16 s3.Bucket(BUCKET_NAME).put_object(Key='currency.csv', Body=data)
#      18 print ("Done")
#
# File ~\Anaconda3\lib\site-packages\boto3\resources\factory.py:580, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     579 def do_action(self, *args, **kwargs):
# --> 580     response = action(self, *args, **kwargs)
#     582     if hasattr(self, 'load'):
#     583         # Clear cached data. It will be reloaded the next
#     584         # time that an attribute is accessed.
# ...

# %%
credentials = yaml.load(open('./credentials.yml'))

# access values from dictionary
username = credentials['database']['username']
